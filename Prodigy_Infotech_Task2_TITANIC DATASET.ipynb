# %% [markdown]
# # PRODIGY INFOTECH TASK 2
# Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the titanic dataset

titanic_df=pd.read_csv(r"C:\Users\MAHDI ISMAIL\Downloads\titanic_train.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Top 5 record of the dataset

titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in titanic_df.columns:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
# Stats about the dataset
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Total passengers Male and Female
titanic_df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#Creating a chart for male and female passengers
sns.catplot(x="Sex",data=titanic_df,kind="count",ec='black',lw=2)
plt.title("Sex",fontsize=18)
plt.xlabel("Name of the Sex",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.grid(True)
plt.show()

# %%
# Count of the passengers on differnt class

titanic_df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
# making a chart for passengers in different class

sns.catplot(x="Pclass",data=titanic_df,kind="count",ec="black",lw=2)
plt.title("CLASS",fontsize=18)
plt.xlabel("Name of the class",fontsize=13,color='red')
plt.ylabel("Number of Passengers",fontsize=13,color='red')
plt.grid(True)
plt.show()

# %%
#Which class has more passengers male and female
sns.catplot(x='Sex',data=titanic_df,kind='count',ec='black',lw=2,hue='Pclass')
plt.title("PREFERRED CLASS",fontsize=18)
plt.xlabel("Name of the Sex",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 2
#       1 #Which class has more passengers male and female
# ----> 2 sns.catplot(x='Sex',data=titanic_df,kind='count',ec='black',lw=2,hue='Pclass')
#       3 plt.title("PREFERRED CLASS",fontsize=18)
#       4 plt.xlabel("Name of the Sex",fontsize=13)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3244, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# -> 3244 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3246 if p.orient == "h":
# ...

# %%
#Creating a function if a person is man,women or child

def man_wom_chi(passenger):
    age=passenger['Age']
    sex=passenger['Sex']
    return 'child' if age < 16 else sex

# %%
#Creating a new column in the data set
titanic_df['Person']=titanic_df.apply(man_wom_chi,axis=1)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person
# 0      0         A/5 21171   7.2500   NaN        S    male
# 1      0          PC 17599  71.2833   C85        C  female
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female
# 3      0            113803  53.1000  C123        S  female
# ...

# %%
# Count of the Person column of the dataset.
titanic_df['Person'].value_counts()
# Out:
# Person
# male      537
# female    271
# child      83
# Name: count, dtype: int64

# %%
# Name of the category of the passengers.
x=list(titanic_df['Person'].value_counts().keys())
x
# Out:
# ['male', 'female', 'child']

# %%
# Number of the passengers of the different category.
y=list(titanic_df['Person'].value_counts())
y
# Out:
# [537, 271, 83]

# %%
# Bar - plot for number of male, female and child passengers on the Titanic.
plt.figure(figsize=(10,5))
plt.bar(x,y,color=['red','yellow','green'],ec='black',lw=2)
plt.grid(True)
plt.title("PERSON",fontsize=15)
plt.xlabel('Category of the Passengers',fontsize=13)
plt.ylabel('Number of Passengers',fontsize=13)
plt.show()

# %%
# Catplot to find which of the class on the Titanic has most number of childrens.
sns.catplot(x='Pclass',data=titanic_df,kind='count',hue='Person',ec='black',lw=2)
plt.title("PREFERRED CLASS",fontsize=18)
plt.xlabel("Name of the Class",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.grid(True)
plt.show()

# %%
# Counts of the age of the passengers.
titanic_df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
# Displot for the Age column of the dataset.
sns.displot(titanic_df['Age'],color="purple",kde=True,bins=25)
plt.title("AGE",fontsize=15)
plt.ylabel('Number of the Passengers',fontsize=13)
plt.xlabel('Age of the Passengers',fontsize=13)
plt.grid(True)
plt.show()

# %%
# Create a plot which tells about the age and classes of the passengers.
fig=sns.FacetGrid(titanic_df,hue='Pclass',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
oldest=titanic_df['Age'].max()
fig.set(xlim=(0,oldest))
fig.add_legend()
plt.title("AGE VS CLASS",fontsize=18)
plt.xlabel("Age of the Passengers",fontsize=12)
plt.ylabel("Density of Passengers",fontsize=12)
plt.grid(False)
plt.show()
# Out:
# C:\Users\MAHDI ISMAIL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\MAHDI ISMAIL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\MAHDI ISMAIL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Create a plot which tells us about the Age and Sex of the passengers.
fig=sns.FacetGrid(titanic_df,hue='Sex',aspect=4)
fig.map(sns.kdeplot,'Age',shade=True)
fig.set(xlim=(0,oldest))
oldest=titanic_df['Age'].max()
fig.add_legend()
plt.title("AGE VS SEX",fontsize=18)
plt.xlabel("Age of the Passengers",fontsize=12)
plt.ylabel("Density of Passengers",fontsize=12)
plt.show()
# Out:
# C:\Users\MAHDI ISMAIL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\MAHDI ISMAIL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %%
# Create a dataset deck_df and we just drop the missing data in Cabin column.
deck_df=titanic_df.dropna(axis=0)
deck_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Head of the datatset.
deck_df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Person
# 1       0  PC 17599  71.2833   C85        C  female
# 3       0    113803  53.1000  C123        S  female
# 6       0     17463  51.8625   E46        S    male
# 10      1   PP 9549  16.7000    G6        S   child
# ...

# %%
# Create a function to extract level from the Cabin column.
def get_level(passenger):
    cabin=passenger['Cabin']
    return cabin[0]

# %%
# To avoid settingWithCopyWarning.

pd.options.mode.chained_assignment=None

# Create a new column level in the deck_df column.
deck_df['level']=deck_df.apply(get_level,axis=1)

# Head of the datatset after adding new column level in it.
deck_df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Person level
# 1       0  PC 17599  71.2833   C85        C  female     C
# 3       0    113803  53.1000  C123        S  female     C
# 6       0     17463  51.8625   E46        S    male     E
# 10      1   PP 9549  16.7000    G6        S   child     G
# ...

# %%
# Catplot for finding which deck has most number of passengers.
sns.catplot(x='level',data=deck_df,kind='count',ec='black',lw=2)
plt.title("DECK",fontsize=18)
plt.xlabel("Name of the Deck",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.grid(True)
plt.show()
print('From the above, we can say that most of the passengers belong to deck C on Titanic.')
# Out:
# From the above, we can say that most of the passengers belong to deck C on Titanic.

# %% [markdown]
# # Relation between the class and Deck of the passengers ?

# %%
# Catplot bw class and deck of the passengers.
sns.catplot(x='level',data=deck_df,kind='count',hue='Pclass',ec='black',lw=2)
plt.title("DECK VS CLASS",fontsize=18)
plt.xlabel("Name of the Deck",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Catplot bw class and deck of the passengers.
# ----> 2 sns.catplot(x='level',data=deck_df,kind='count',hue='Pclass',ec='black',lw=2)
#       3 plt.title("DECK VS CLASS",fontsize=18)
#       4 plt.xlabel("Name of the Deck",fontsize=13)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3244, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# -> 3244 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3246 if p.orient == "h":
# ...

# %%
# Count of the various passengers'city.
titanic_df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Name of the passengers.
x=list(titanic_df['Embarked'].value_counts().keys())
x
# Out:
# ['S', 'C', 'Q']

# %%
y=list(titanic_df['Embarked'].value_counts())
y
# Out:
# [644, 168, 77]

# %%
# Count-plot about the city of the passengers.
sns.countplot(data = titanic_df,x = 'Embarked',ec='black',lw=2)
plt.title("CITY",fontsize=17)
plt.grid(True)
plt.xlabel("Name of the City",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.show()

# %%
# Catplot bw city and class of the passengers.
sns.catplot(x='Embarked',data=titanic_df,kind='count',hue='Pclass',ec='black',lw=1)
plt.title("City VS CLASS",fontsize=18)
plt.xlabel("Name of the City",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Catplot bw city and class of the passengers.
# ----> 2 sns.catplot(x='Embarked',data=titanic_df,kind='count',hue='Pclass',ec='black',lw=1)
#       3 plt.title("City VS CLASS",fontsize=18)
#       4 plt.xlabel("Name of the City",fontsize=13)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3244, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3241 g = FacetGrid(**facet_kws)
#    3243 # Draw the plot onto the facets
# -> 3244 g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3246 if p.orient == "h":
# ...

# %%
# Count of the Sibsp column of the datatset.Sibsp column contains data of number of siblings or spouse of the passenger. 
titanic_df.SibSp
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64

# %%
# Count of the Parch column of the datatset.Parch column contains data of number of parents or childrens of the passenger.
titanic_df.Parch
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64

# %%
# Adding the number of family a passenger had onboard.
titanic_df['Alone']=titanic_df.SibSp + titanic_df.Parch
titanic_df['Alone']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    3
# 889    0
# 890    0
# Name: Alone, Length: 891, dtype: int64

# %%
# Head of the dataset.
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person  Alone
# 0      0         A/5 21171   7.2500   NaN        S    male      1
# 1      0          PC 17599  71.2833   C85        C  female      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female      0
# ...

# %%
# Tail of the datatset.
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Person  \
# 886    male  27.0      0      0      211536  13.00   NaN        S    male
# 887  female  19.0      0      0      112053  30.00   B42        S  female
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S  female
# 889    male  26.0      0      0      111369  30.00  C148        C    male
# 890    male  32.0      0      0      370376   7.75   NaN        Q    male
#
#      Alone
# 886      0
# 887      0
# 888      3
# ...

# %%
# Where Alone has 0 value assign Yes and where Alone has value greater than 1 assign No.
titanic_df['Alone'].loc[titanic_df['Alone']>0] = 'No'
titanic_df['Alone'].loc[titanic_df['Alone']==0] = 'Yes'

# %%
# Head of the datatset.
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Person Alone
# 0      0         A/5 21171   7.2500   NaN        S    male    No
# 1      0          PC 17599  71.2833   C85        C  female    No
# 2      0  STON/O2. 3101282   7.9250   NaN        S  female   Yes
# ...

# %%
# Catplot whether the passenger is travelling with family or without family members.
sns.catplot(data=titanic_df,x='Alone',kind='count',ec='black',lw=2)
plt.title("FAMILY",fontsize=18)
plt.grid(True)
plt.show()

# %%
# Count-plot about survival of the passengers.
sns.countplot(data = titanic_df,x = 'Survived',ec='black',lw=1,palette='crest')
plt.grid(True)
plt.xlabel("Survived",fontsize=13)
plt.ylabel("Number of Passengers",fontsize=13)
plt.show()

# %%
# Cat-plot about class of the passengers who survived.
sns.catplot(data = titanic_df,x ='Pclass',y='Survived',kind='point')
plt.grid(True)
plt.ylabel("Survived",fontsize=13)
plt.xlabel("Class of the Passengers",fontsize=13)
plt.show()

# %%
# Cat-plot about class and gender of the passengers who have less chances of survival.
sns.catplot(data=titanic_df,x='Pclass',y='Survived',kind='point',hue='Person')
plt.grid(True)
plt.ylabel("Survived",fontsize=13)
plt.xlabel("Class of the Passengers",fontsize=13)
plt.show()
print("From the above, we can say that male has less chance of survived than female or child on the Titanic.Among females passengers and child passengers those who are on the class 3 have less chances of survival than that of class 1 and class 2.")
# Out:
# From the above, we can say that male has less chance of survived than female or child on the Titanic.Among females passengers and child passengers those who are on the class 3 have less chances of survival than that of class 1 and class 2.

# %%
# Create lmplot to check the chances of survival of the passengers on the basis of their age.
sns.lmplot(data=titanic_df,x='Age',y='Survived')
plt.ylabel("Survived",fontsize=13)
plt.xlabel("Age of the Passengers",fontsize=13)
plt.grid(True)
plt.show()

# %%
# Create lmplot to check the chances of survival of the passengers on the basis of their age and class.
sns.lmplot(data=titanic_df,x='Age',y='Survived',hue='Pclass')
plt.ylabel("Survived",fontsize=13)
plt.xlabel("Age of the Passengers",fontsize=13)
plt.grid(True)
plt.show()
print('From the above we can say that, the passengers who have younger in age and of class 1 has greater chances of survival than that of who have older age and of class 3.')
# Out:
# From the above we can say that, the passengers who have younger in age and of class 1 has greater chances of survival than that of who have older age and of class 3.
